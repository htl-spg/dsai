# %% [markdown]
# # Data Science und AI Einführung Handout
#
# > **_Klasse:_**  _________________________________________________________________\
# \
# > **_Name:_**  __________________________________________________________________
#
#
# ### 1. Aufgabe
# Warum heben Data Science und AI so ab?
#
# - [ ] Mehr Daten, bessere CPUs und GPUs
# - [ ] Mehr Daten, bessere Rechenleistung und Algorithmen
# - [ ] Mehr Daten, bessere Rechenleistung und CPUs
# - [ ] Bessere Rechenleistung, Algorithmen und GPUs
#
# <!-- Richtige Antwort 2 -->
#
# ### 2. Aufgabe
# Dank Data Science hat man in der NBA herausgefunden, dass ...
#
# - [ ] viele 1-Punkte Würfe die beste Spielstrategie ist.
# - [ ] viele 2-Punkte Würfe die beste Spielstrategie ist.
# - [ ] viele 3-Punkte Würfe die beste Spielstrategie ist.
# - [ ] viele Fouls die beste Spielstrategie ist.
#
# <!-- Richtige Antwort 3 -->
#
# ### 3. Aufgabe
# Der CRISP-DM Prozess besteht aus folgenden Teilen:
#
# - [ ] Data Understanding, Data Preparation, Modelling, Evaluation und Deployment
# - [ ] Business Understanding, Data Understanding, Data Preparation, Modelling und Evaluation
# - [ ] Business Understanding, Data Understanding, Data Preparation, Data Cleaning, Modelling, Evaluation und Deployment
# - [ ] Business Understanding, Data Understanding, Data Preparation, Modelling, Evaluation und Deployment
#
# <!-- Richtige Antwort 4 -->
#
# ### 4. Aufgabe
# Folgende Daten sind ...
#
# Name | Alter | Rasse | Temperatur (Celsius) | Gewicht (kg) | Familientauglich (Gut, Mittel, Schlecht)
# :-- | :-- | :-- | :-- | :-- | :--
# Buddy | 4 | Labrador | 38.5 | 30 | Gut
# Max | 2 | Deutscher Schäferhund | 39.2 | 35 | Mittel
# Luna | 3 | Golden Retriever | 37.8 | 28 | Gut
# Rocky | 5 | Bulldogge | 38.0 | 22 | Mittel
#
# - [ ] Name und Rasse sind nominal skaliert
# - [ ] Strukturierte Daten
# - [ ] Name und Rasse sind ordinal skaliert
# - [ ] Unstrukturiert Daten
# - [ ] Temperatur und Gewicht sind kardinal skaliert
# - [ ] Familientauglichkeit ist ordinal skaliert
#
# <!-- Richtige Antworten 1, 2, 5, 6 -->
#
# ### 5. Aufgabe
#
# Laut dem DSGVO darf ich ein Foto von mir und einem bekannten, ohne dessen Zustimmung, auf Instagram hochladen?
#
# - [ ] Ja
# - [ ] Nein
#
# <!-- Richtige Antwort 2 -->
#
# ### 6. Aufgabe
# Die 5 V's von Big Data sind?
#
# - [ ] Velocity, Veil, Variety, Veracity und Value
# - [ ] Velocimetry, Volumne, Variety, Veracity und Value
# - [ ] Velocity, Volumne, Variety, Veracity und Value
# - [ ] Velocity, Volumne, Variety, Venality und Value
#
# <!-- Richtige Antwort 3 -->
#
# ### 7. Aufgabe
# Ein ausgewähltes Merkmal sollte ...
# - [ ] kombinierbar sein
# - [ ] einfach und schnell zu berechnen sein
# - [ ] nur 80% Fehler beinhalten
# - [ ] gut zwischen Klassen unterscheiden können
#
# <!-- Richtige Antwort 2,4 -->
#
# ### 8. Aufgabe
# Ein gutes Modell sollte
# - [ ] möglichst viele Parameter besitzen
# - [ ] Generalisierbar sein und die Fehler minimieren
# - [ ] Möglichst viele Objekte erkennen
# - [ ] Mittlere Komplexität aufweisen
#
# <!-- Richtige Antwort 2 -->
